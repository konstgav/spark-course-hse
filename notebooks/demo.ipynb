# %%
import sys
sys.path.append("../host")
from spark_session import get_spark

spark = get_spark("lab-01")          # 2 executor'а по 1 ядру/1g — по одному на каждом воркере

spark.sql("CREATE NAMESPACE IF NOT EXISTS iceberg.demo")
spark.sql("CREATE TABLE IF NOT EXISTS iceberg.demo.t (id BIGINT, name STRING) USING iceberg")
spark.sql("INSERT INTO iceberg.demo.t VALUES (1, 'a')")
spark.table("iceberg.demo.t").show()
# Out:
# 26/09/13 16:17:51 WARN Utils: Your hostname, konst-labtop resolves to a loopback address: 127.0.1.1; using 192.168.0.10 instead (on interface wlp0s20f3)
# 26/09/13 16:17:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/konst/miniconda3/envs/spark-course/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/konst/.ivy2/cache
# The jars for the packages stored in: /home/konst/.ivy2/jars
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# ai.catboost#catboost-spark_3.5_2.12 added as a dependency
# org.postgresql#postgresql added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-9f0fdccd-80f9-4156-a72f-f13087d28c5f;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.10.1 in central
# 	found ai.catboost#catboost-spark_3.5_2.12;1.2.10 in central
# 	found org.scala-lang.modules#scala-collection-compat_2.12;2.6.0 in central
# 	found com.google.guava#guava;32.0.0-jre in central
# 	found com.google.guava#failureaccess;1.0.1 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;3.33.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.18.0 in central
# 	found com.google.j2objc#j2objc-annotations;2.8 in central
# 	found commons-io#commons-io;2.14.0 in central
# 	found org.apache.commons#commons-lang3;3.18.0 in central
# 	found org.apache.commons#commons-text;1.10.0 in central
# 	found commons-validator#commons-validator;1.10.1 in central
# 	found commons-beanutils#commons-beanutils;1.11.0 in central
# 	found commons-logging#commons-logging;1.3.5 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found commons-digester#commons-digester;2.1 in central
# 	found org.json4s#json4s-jackson_2.12;3.7.0-M11 in central
# 	found org.json4s#json4s-core_2.12;3.7.0-M11 in central
# 	found org.json4s#json4s-ast_2.12;3.7.0-M11 in central
# 	found org.json4s#json4s-scalap_2.12;3.7.0-M11 in central
# 	found com.thoughtworks.paranamer#paranamer;2.8 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.15.2 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.15.2 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.15.2 in central
# 	found com.fasterxml.jackson.module#jackson-module-scala_2.12;2.15.2 in central
# 	found io.github.classgraph#classgraph;4.8.112 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.4 in central
# 	found ai.catboost#catboost-common;1.2.10 in central
# 	found javax.validation#validation-api;1.1.0.Final in central
# 	found org.slf4j#slf4j-api;1.7.25 in central
# 	found ai.catboost#catboost-spark-macros_2.12;1.2.10 in central
# 	found org.scala-lang#scala-reflect;2.12.20 in central
# 	found org.postgresql#postgresql;42.7.8 in central
# 	found org.checkerframework#checker-qual;3.49.5 in central
# downloading https://repo1.maven.org/maven2/org/apache/iceberg/iceberg-spark-runtime-3.5_2.12/1.10.1/iceberg-spark-runtime-3.5_2.12-1.10.1.jar ...
# 	[SUCCESSFUL ] org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.10.1!iceberg-spark-runtime-3.5_2.12.jar (4574ms)
# downloading https://repo1.maven.org/maven2/ai/catboost/catboost-spark_3.5_2.12/1.2.10/catboost-spark_3.5_2.12-1.2.10.jar ...
# 	[SUCCESSFUL ] ai.catboost#catboost-spark_3.5_2.12;1.2.10!catboost-spark_3.5_2.12.jar (4208ms)
# downloading https://repo1.maven.org/maven2/org/postgresql/postgresql/42.7.8/postgresql-42.7.8.jar ...
# 	[SUCCESSFUL ] org.postgresql#postgresql;42.7.8!postgresql.jar (351ms)
# downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-collection-compat_2.12/2.6.0/scala-collection-compat_2.12-2.6.0.jar ...
# 	[SUCCESSFUL ] org.scala-lang.modules#scala-collection-compat_2.12;2.6.0!scala-collection-compat_2.12.jar (261ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/guava/32.0.0-jre/guava-32.0.0-jre.jar ...
# 	[SUCCESSFUL ] com.google.guava#guava;32.0.0-jre!guava.jar(bundle) (441ms)
# downloading https://repo1.maven.org/maven2/commons-io/commons-io/2.14.0/commons-io-2.14.0.jar ...
# 	[SUCCESSFUL ] commons-io#commons-io;2.14.0!commons-io.jar (313ms)
# downloading https://repo1.maven.org/maven2/org/apache/commons/commons-lang3/3.18.0/commons-lang3-3.18.0.jar ...
# 	[SUCCESSFUL ] org.apache.commons#commons-lang3;3.18.0!commons-lang3.jar (234ms)
# downloading https://repo1.maven.org/maven2/org/apache/commons/commons-text/1.10.0/commons-text-1.10.0.jar ...
# 	[SUCCESSFUL ] org.apache.commons#commons-text;1.10.0!commons-text.jar (201ms)
# downloading https://repo1.maven.org/maven2/commons-validator/commons-validator/1.10.1/commons-validator-1.10.1.jar ...
# 	[SUCCESSFUL ] commons-validator#commons-validator;1.10.1!commons-validator.jar (202ms)
# downloading https://repo1.maven.org/maven2/org/json4s/json4s-jackson_2.12/3.7.0-M11/json4s-jackson_2.12-3.7.0-M11.jar ...
# 	[SUCCESSFUL ] org.json4s#json4s-jackson_2.12;3.7.0-M11!json4s-jackson_2.12.jar (201ms)
# downloading https://repo1.maven.org/maven2/com/fasterxml/jackson/core/jackson-databind/2.15.2/jackson-databind-2.15.2.jar ...
# 	[SUCCESSFUL ] com.fasterxml.jackson.core#jackson-databind;2.15.2!jackson-databind.jar (287ms)
# downloading https://repo1.maven.org/maven2/com/fasterxml/jackson/module/jackson-module-scala_2.12/2.15.2/jackson-module-scala_2.12-2.15.2.jar ...
# 	[SUCCESSFUL ] com.fasterxml.jackson.module#jackson-module-scala_2.12;2.15.2!jackson-module-scala_2.12.jar(bundle) (321ms)
# downloading https://repo1.maven.org/maven2/io/github/classgraph/classgraph/4.8.112/classgraph-4.8.112.jar ...
# 	[SUCCESSFUL ] io.github.classgraph#classgraph;4.8.112!classgraph.jar (219ms)
# downloading https://repo1.maven.org/maven2/org/xerial/snappy/snappy-java/1.1.10.4/snappy-java-1.1.10.4.jar ...
# 	[SUCCESSFUL ] org.xerial.snappy#snappy-java;1.1.10.4!snappy-java.jar(bundle) (358ms)
# downloading https://repo1.maven.org/maven2/ai/catboost/catboost-common/1.2.10/catboost-common-1.2.10.jar ...
# 	[SUCCESSFUL ] ai.catboost#catboost-common;1.2.10!catboost-common.jar (185ms)
# downloading https://repo1.maven.org/maven2/ai/catboost/catboost-spark-macros_2.12/1.2.10/catboost-spark-macros_2.12-1.2.10.jar ...
# 	[SUCCESSFUL ] ai.catboost#catboost-spark-macros_2.12;1.2.10!catboost-spark-macros_2.12.jar (189ms)
# downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.12.20/scala-reflect-2.12.20.jar ...
# 	[SUCCESSFUL ] org.scala-lang#scala-reflect;2.12.20!scala-reflect.jar (897ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/failureaccess/1.0.1/failureaccess-1.0.1.jar ...
# 	[SUCCESSFUL ] com.google.guava#failureaccess;1.0.1!failureaccess.jar(bundle) (194ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/listenablefuture/9999.0-empty-to-avoid-conflict-with-guava/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar ...
# 	[SUCCESSFUL ] com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava!listenablefuture.jar (230ms)
# downloading https://repo1.maven.org/maven2/com/google/code/findbugs/jsr305/3.0.2/jsr305-3.0.2.jar ...
# 	[SUCCESSFUL ] com.google.code.findbugs#jsr305;3.0.2!jsr305.jar (191ms)
# downloading https://repo1.maven.org/maven2/com/google/errorprone/error_prone_annotations/2.18.0/error_prone_annotations-2.18.0.jar ...
# 	[SUCCESSFUL ] com.google.errorprone#error_prone_annotations;2.18.0!error_prone_annotations.jar (200ms)
# downloading https://repo1.maven.org/maven2/com/google/j2objc/j2objc-annotations/2.8/j2objc-annotations-2.8.jar ...
# 	[SUCCESSFUL ] com.google.j2objc#j2objc-annotations;2.8!j2objc-annotations.jar (223ms)
# downloading https://repo1.maven.org/maven2/commons-beanutils/commons-beanutils/1.11.0/commons-beanutils-1.11.0.jar ...
# 	[SUCCESSFUL ] commons-beanutils#commons-beanutils;1.11.0!commons-beanutils.jar (261ms)
# downloading https://repo1.maven.org/maven2/commons-digester/commons-digester/2.1/commons-digester-2.1.jar ...
# 	[SUCCESSFUL ] commons-digester#commons-digester;2.1!commons-digester.jar (270ms)
# downloading https://repo1.maven.org/maven2/commons-logging/commons-logging/1.3.5/commons-logging-1.3.5.jar ...
# 	[SUCCESSFUL ] commons-logging#commons-logging;1.3.5!commons-logging.jar (293ms)
# downloading https://repo1.maven.org/maven2/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar ...
# 	[SUCCESSFUL ] commons-collections#commons-collections;3.2.2!commons-collections.jar (307ms)
# downloading https://repo1.maven.org/maven2/org/json4s/json4s-core_2.12/3.7.0-M11/json4s-core_2.12-3.7.0-M11.jar ...
# 	[SUCCESSFUL ] org.json4s#json4s-core_2.12;3.7.0-M11!json4s-core_2.12.jar (334ms)
# downloading https://repo1.maven.org/maven2/org/json4s/json4s-ast_2.12/3.7.0-M11/json4s-ast_2.12-3.7.0-M11.jar ...
# 	[SUCCESSFUL ] org.json4s#json4s-ast_2.12;3.7.0-M11!json4s-ast_2.12.jar (292ms)
# downloading https://repo1.maven.org/maven2/org/json4s/json4s-scalap_2.12/3.7.0-M11/json4s-scalap_2.12-3.7.0-M11.jar ...
# 	[SUCCESSFUL ] org.json4s#json4s-scalap_2.12;3.7.0-M11!json4s-scalap_2.12.jar (284ms)
# downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.8/paranamer-2.8.jar ...
# 	[SUCCESSFUL ] com.thoughtworks.paranamer#paranamer;2.8!paranamer.jar(bundle) (281ms)
# downloading https://repo1.maven.org/maven2/com/fasterxml/jackson/core/jackson-annotations/2.15.2/jackson-annotations-2.15.2.jar ...
# 	[SUCCESSFUL ] com.fasterxml.jackson.core#jackson-annotations;2.15.2!jackson-annotations.jar (214ms)
# downloading https://repo1.maven.org/maven2/com/fasterxml/jackson/core/jackson-core/2.15.2/jackson-core-2.15.2.jar ...
# 	[SUCCESSFUL ] com.fasterxml.jackson.core#jackson-core;2.15.2!jackson-core.jar (319ms)
# downloading https://repo1.maven.org/maven2/javax/validation/validation-api/1.1.0.Final/validation-api-1.1.0.Final.jar ...
# 	[SUCCESSFUL ] javax.validation#validation-api;1.1.0.Final!validation-api.jar (207ms)
# downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.25/slf4j-api-1.7.25.jar ...
# 	[SUCCESSFUL ] org.slf4j#slf4j-api;1.7.25!slf4j-api.jar (214ms)
# downloading https://repo1.maven.org/maven2/org/checkerframework/checker-qual/3.49.5/checker-qual-3.49.5.jar ...
# 	[SUCCESSFUL ] org.checkerframework#checker-qual;3.49.5!checker-qual.jar (248ms)
# :: resolution report :: resolve 47325ms :: artifacts dl 18047ms
# 	:: modules in use:
# 	ai.catboost#catboost-common;1.2.10 from central in [default]
# 	ai.catboost#catboost-spark-macros_2.12;1.2.10 from central in [default]
# 	ai.catboost#catboost-spark_3.5_2.12;1.2.10 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.15.2 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.15.2 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.15.2 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-scala_2.12;2.15.2 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.18.0 from central in [default]
# 	com.google.guava#failureaccess;1.0.1 from central in [default]
# 	com.google.guava#guava;32.0.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.j2objc#j2objc-annotations;2.8 from central in [default]
# 	com.thoughtworks.paranamer#paranamer;2.8 from central in [default]
# 	commons-beanutils#commons-beanutils;1.11.0 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-digester#commons-digester;2.1 from central in [default]
# 	commons-io#commons-io;2.14.0 from central in [default]
# 	commons-logging#commons-logging;1.3.5 from central in [default]
# 	commons-validator#commons-validator;1.10.1 from central in [default]
# 	io.github.classgraph#classgraph;4.8.112 from central in [default]
# 	javax.validation#validation-api;1.1.0.Final from central in [default]
# 	org.apache.commons#commons-lang3;3.18.0 from central in [default]
# 	org.apache.commons#commons-text;1.10.0 from central in [default]
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.10.1 from central in [default]
# 	org.checkerframework#checker-qual;3.49.5 from central in [default]
# 	org.json4s#json4s-ast_2.12;3.7.0-M11 from central in [default]
# 	org.json4s#json4s-core_2.12;3.7.0-M11 from central in [default]
# 	org.json4s#json4s-jackson_2.12;3.7.0-M11 from central in [default]
# 	org.json4s#json4s-scalap_2.12;3.7.0-M11 from central in [default]
# 	org.postgresql#postgresql;42.7.8 from central in [default]
# 	org.scala-lang#scala-reflect;2.12.20 from central in [default]
# 	org.scala-lang.modules#scala-collection-compat_2.12;2.6.0 from central in [default]
# 	org.slf4j#slf4j-api;1.7.25 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.4 from central in [default]
# 	:: evicted modules:
# 	org.checkerframework#checker-qual;3.33.0 by [org.checkerframework#checker-qual;3.49.5] in [default]
# 	org.apache.commons#commons-lang3;3.12.0 by [org.apache.commons#commons-lang3;3.18.0] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.2 by [com.fasterxml.jackson.core#jackson-databind;2.15.2] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   38  |   36  |   36  |   3   ||   35  |   35  |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-9f0fdccd-80f9-4156-a72f-f13087d28c5f
# 	confs: [default]
# 	35 artifacts copied, 0 already retrieved (118925kB/68ms)
# 26/09/13 16:18:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# +---+----+
# | id|name|
# +---+----+
# |  1|   a|
# +---+----+

# %%
spark.stop()
